# %%
import pandas as pd
import numpy as np
import seaborn as sns
import csv
from matplotlib import pyplot as plt
import matplotlib.animation as animation
from matplotlib.animation import FuncAnimation
from IPython import display

# %%
lambda0 = 180.
xi0 = 2.

T=1.
Tc=84.
length = 2.*10**3
width = 2.*10**3
lambda0 = 180.0

lambda1 = lambda0*(1-(T/Tc)**3.3)**(-1./2.)
xi = xi0*(1-(T/Tc)**3.3)**(-1./2.)
alpha = 1.

phi0 = 2.06783460999999E-07
delta = 0.27
U0 = phi0**2/(8.*np.pi**2*lambda1**2*10.**(-14)) * delta*10.**(-7)

# %%
xdefs = np.linspace(-length/2.+0.41*lambda0, length/2.-0.41*lambda0, 10)
ydefs = np.linspace(-width/2.+0.41*lambda0, width/2.-0.41*lambda0, 10)
a=np.zeros((100,2))
for i in range(10):
  for j in range(10):
    a[10*i+j, :] = (xdefs[i], ydefs[j])
X=a[:,0]
Y=a[:,1]
M=len(a)
b =[]
with open("defs1.txt", "w") as f:
     f.write(str(M))
     f.write('\n')
     for i in range(M):
       f.write(str(a[i,0])+' '+ str(a[i,1])+'\n')
       b.append(str(a[i,0])+' '+ str(a[i,1])+'\n')
plt.scatter(X, Y)
plt.xlim(-2500, 2500)
plt.ylim(-2500, 2500)
# Out:
# (-2500.0, 2500.0)

# %%
import seaborn as sns
import csv
from matplotlib import pyplot as plt
f = open("defsnet.txt")
a = []
for line in f:
    a.append(line.split())
f1 = open("defsnet1.txt", 'w')
for i in range(1,4001):
    f1.write(str(i))
    f1.write(',')
f1.write(str(4001))
f1.write('\n')
for i in a:
    f1.write(','.join(i))
    f1.write('\n')
f.close()
f1.close()

dataframe1 = pd.read_csv("defsnet1.txt")
dataframe1.to_csv('defsnet1.csv',
                  index = None)
df = pd.read_csv('defsnet1.csv')

# %%
sns.heatmap(df)
# Out:
# <Axes: >

# %%
xdefs = np.array([np.random.uniform(-2000, 2000) for i in range(40)])
ydefs = np.array([np.random.uniform(-2000, 2000) for i in range(40)])
a = np.zeros((40,2))
for i in range(40):
  a[i][0]=xdefs[i]
  a[i][1]=ydefs[i]
X=a[:,0]
Y=a[:,1]
plt.scatter(X,Y)
M = 40
b=[]
with open("defsrandom.txt", "w") as f:
    f.write(str(M))
    f.write('\n')
    for i in range(M):
      f.write(str(a[i,0])+' '+ str(a[i,1])+'\n')
      b.append(str(a[i,0])+' '+ str(a[i,1])+'\n')
print(b)
# Out:
# ['-402.93549092481044 726.957416546441\n', '859.2495187926838 -1241.6202623630265\n', '-789.0644665012699 -1274.2269619763879\n', '-707.7776652693601 143.91379806983196\n', '1346.799379916758 -1862.038936726559\n', '1891.6885438087738 1315.6597590630226\n', '1377.0347329450556 261.8243933210206\n', '-265.5268760231295 -1665.5643117514746\n', '-746.4942809779643 -1025.0660042734262\n', '1163.7144496410292 -1352.5607021420165\n', '1403.4244163213111 -41.450785383121456\n', '-1341.6612865039924 -1356.4313988230783\n', '-292.79487861680263 -426.03329410491847\n', '120.25806555811096 82.14678766218731\n', '-1463.482371296714 -515.1068179951478\n', '-1457.7773586916796 -1892.1085639416426\n', '512.5045680514404 657.9849421581666\n', '-1654.9745775674642 -1521.7875788443616\n', '483.7584280654178 806.7373379704327\n', '-1044.8877407550374 1871.7995098763063\n', '865.4654465680751 210.97149385657076\n', '-153.394591783245 1083.8055745210008\n', '-1506.503296911922 -598.9718732146453\n', '154
# ...

# %%
xdefs = np.array([np.random.uniform(-2000, 2000) for i in range(40)])
ydefs = np.array([np.random.uniform(-2000, 2000) for i in range(40)])
# a=np.zeros((100,2))
# for i in range(10):
#   for j in range(10):
#     a[10*i+j, :] = (xdefs[i], ydefs[j])
# X=a[:,0]
# Y=a[:,1]
# M=len(a)
# b=[]
# with open("defs1.txt", "w") as f:
#     f.write(str(M))
#     f.write('\n')
#     for i in range(M):
#       f.write(str(a[i,0])+' '+ str(a[i,1])+'\n')
#       b.append(str(a[i,0])+' '+ str(a[i,1])+'\n')
# print(b)
# defsnet = np.array(list(range(1,101)))
# defsnet.reshape((10,10))
# with open("defsnet.txt", "w") as f:
#   for i in range(1, M+1):
#     f.write(str(i)+'\n')
plt.scatter(X,Y)

# %%
a=[]
b=[]
with open('defs1.txt', 'r') as datafile:
    plotting = csv.reader(datafile)
    for rows in plotting:
        rows = ''.join(rows).split()
        if len(rows)>1:
          b.append(float(rows[0]))
          b.append(float(rows[1]))
          a.append(b)
          b=[]
a=np.array(a)
plt.scatter(a[:,0], a[:,1])

# %%
X1 = []
Y1 = []
X2 = []
Y2 = []
with open('defs1_20000_h400_t1k_i0.txt', 'r') as datafile:
    plotting = csv.reader(datafile)
    for rows in plotting:
        rows = ''.join(rows).split()
        if float(rows[2])<0.0:
          X1.append(float(rows[0]))
          Y1.append(float(rows[1]))
        else:
          X2.append(float(rows[0]))
          Y2.append(float(rows[1]))
plt.tight_layout()
plt.scatter(a[:,0], a[:, 1],c='red', lw=4)
# plt.scatter(X, Y,c='red', lw=6)
plt.axis([-2500,2500,-2500,2500])
plt.xticks(list(range(-2500,3000,500)))
#plt.title('Распределение вихрей в сверхпроводнике')
plt.scatter(X1,Y1,c='blue')
plt.scatter(X2,Y2,c='blue')
plt.grid()
plt.xlabel('$x, нм$')
plt.ylabel('$y, нм$')
# Out:
# Text(0, 0.5, '$y, нм$')

# %%
X1=[]
xi1=[]
Y1=[]
yi1=[]
X2=[]
xi2=[]
Y2=[]
yi2=[]
with open('animdefs1.txt', 'r') as datafile:
    plotting = csv.reader(datafile)
    for rows in plotting:
      if ''.join(rows) != ' flag':
        rows = ''.join(rows).split()
        if float(rows[2])<0.0:
          xi1.append(float(rows[0]))
          yi1.append(float(rows[1]))
        else:
          xi2.append(float(rows[0]))
          yi2.append(float(rows[1]))
      else:
        X1.append(xi1)
        Y1.append(yi1)
        X2.append(xi2)
        Y2.append(yi2)
        xi1=[]
        yi1=[]
        xi2=[]
        yi2=[]

fig, ax = plt.subplots()
ax.set_xlim(-2500,2500)
ax.set_ylim(-2500,2500)
ims = []
frames=len(X1)
def animate(i):
  ax.clear()
  ax.scatter(a[:,0], a[:,1],c='red', lw=4)
  ax.scatter(X1[i], Y1[i], c='blue')
  ax.scatter(X2[i], Y2[i], c='blue')
  ax.set_xlim(-2500,2500)
  ax.set_ylim(-2500,2500)
  ax.grid()

ani = animation.FuncAnimation(fig, animate, frames=frames, interval=500)

ani.save('anim.gif', writer='pillow')
video = ani.to_html5_video()
html = display.HTML(video)
display.display(html)
# Out:
# <video width="640" height="480" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
import seaborn as sns
import csv
from matplotlib import pyplot as plt
import pandas as pd
f = open("defsnet.txt")
a = []
for line in f:
    a.append(line.split())
f1 = open("defsnet.txt", 'w')
# for i in range(1,401):
#     f1.write(str(i))
#     f1.write(',')
# f1.write(str(401))
# f1.write('\n')
print(len(a))
for i in a:
    f1.write(','.join(i))
    f1.write('\n')
f.close()
f1.close()

dataframe1 = pd.read_csv("defsnet.txt")
dataframe1.to_csv('defsnet.csv',
                  index = None)
df = pd.read_csv('defsnet.csv')

sns.heatmap(df, cmap = 'hot', cbar=False)

plt.xlabel('$x, нм$')
plt.ylabel('$y, нм$')
# Out:
# 174
# Text(50.722222222222214, 0.5, '$y, нм$')

# %%
length = 5000.
width = 5000.
lambda1 = 180
KK = 15
xdefs = np.linspace(-length/2+0.45*lambda1, length/2-0.45*lambda1, KK)
ydefs = np.linspace(-width/2+0.45*lambda1, width/2-0.45*lambda1, KK)
a=np.zeros((KK**2,2))
for i in range(KK):
  for j in range(KK):
    a[KK*i+j, :] = (xdefs[i], ydefs[j])
X=a[:,0]
Y=a[:,1]
M=len(a)
b=[]
with open("defs400_squared.txt", "w") as f:
    f.write(str(M))
    f.write('\n')
    for i in range(M):
      f.write(str(a[i,0])+' '+ str(a[i,1])+'\n')
      b.append(str(a[i,0])+' '+ str(a[i,1])+'\n')
print(b)

plt.scatter(X,Y)
# Out:
# ['-2419.0 -2419.0\n', '-2419.0 -2073.4285714285716\n', '-2419.0 -1727.857142857143\n', '-2419.0 -1382.2857142857142\n', '-2419.0 -1036.7142857142858\n', '-2419.0 -691.1428571428573\n', '-2419.0 -345.57142857142844\n', '-2419.0 0.0\n', '-2419.0 345.57142857142844\n', '-2419.0 691.1428571428569\n', '-2419.0 1036.7142857142853\n', '-2419.0 1382.2857142857142\n', '-2419.0 1727.8571428571431\n', '-2419.0 2073.4285714285716\n', '-2419.0 2419.0\n', '-2073.4285714285716 -2419.0\n', '-2073.4285714285716 -2073.4285714285716\n', '-2073.4285714285716 -1727.857142857143\n', '-2073.4285714285716 -1382.2857142857142\n', '-2073.4285714285716 -1036.7142857142858\n', '-2073.4285714285716 -691.1428571428573\n', '-2073.4285714285716 -345.57142857142844\n', '-2073.4285714285716 0.0\n', '-2073.4285714285716 345.57142857142844\n', '-2073.4285714285716 691.1428571428569\n', '-2073.4285714285716 1036.7142857142853\n', '-2073.4285714285716 1382.2857142857142\n', '-2073.4285714285716 1727.8571428571431\n', '-2
# ...

# %%
laplas_=[(-10.538140515064,-28.8403497054693),(-9.3027160172741,-9.691269989726),(-9.9204282661691,8.8400974771223), (-9.3027160172741,30.4600261884454), E=(-8.6850037683792,50.2268181530837), F=(-10.538140515064,-47.3717171723177), G=(-10.538140515064,-69.6093581325357),H=(-10.538140515064,-90.6115745949638),I=(-11.155852763959,-110.996078808497), (-11.155852763959, -128.2920217775555),]

# %%
laplas_=[(-10.538140515064, -28.8403497054693),
(-9.3027160172741, -9.691269989726),(-9.9204282661691, 8.8400974771223),(-9.3027160172741, 30.4600261884454),
 (-8.6850037683792, 50.2268181530837),(-10.538140515064, -47.3717171723177),(-10.538140515064, -69.6093581325357),
  (-10.538140515064, -90.6115745949638),
(-11.155852763959, -110.996078808497),(-11.155852763959, -128.2920217775555)]

# %%
ggg =''' A = (-103.3269000955246, -1558.4177096088904)
B = (-317.7064509317644, -1440.5089566489587)
C = (-510.6480466843802, -1258.2863384381553)
D = (-639.2757771861241, -1124.2991191655058)
E = (-746.465552604244, -963.5144560383262)
F = (-853.6553280223638, -781.2918378275228)
G = (-928.6881708150478, -615.1476859294373)
H = (-1035.8779462331677, -427.565578947728)
I = (-1105.5513002549455, -320.3758035296083)
J = (-1196.6626093603475, -164.9506291733349)
K = (-1266.3359633821256, 70.8668767465284)
L = (-1319.9308510911853, 215.5730735609899)
M = (-1362.8067612584334, 365.6387591463574)
N = (-1394.9636938838694, 585.3777987535027)
O = (-1437.8396040511172, 906.9471250078616)
(0, -1638.81004117248)
Q = (105.6931619698092, -1563.7771983797963)
R = (212.8829373879291, -1445.8684454198647)
S = (-1000, 1500)
T = (-1116.2702777967577, 1405.379580702118)
U = (-1228.8195419857834, 1308.9087828258102)
V = (-1341.3688061748094, 1212.4379849495026)
W = (-1405.6826714256813, 1099.888720760477)
Z = (-869.7337943350818, 1496.4908898075196) A1
 = (-757.184530146056, 1453.614979640272) B1
 = (-649.9947547279361, 1373.2226480766822) C1
 = (-532.0860017680042, 1266.0328726585624) D1
 = (-382.0203161826363, 1153.4836084695369) E1
 = (-248.0330969099865, 1062.3722993641352) F1
 = (-114.0458776373366, 944.4635464042035) G1
 = (700.5964155403747, 1501.8503785784258) H1
 = (500, 1500)
I1
 = (389.746066827827, 1394.660603160306) J1
 = (309.353735264237, 1298.1898052839983) K1
 = (202.1639598461171, 1191.0000298658788) L1
 = (84.2552068861852, 1067.7317881350411)
(0, 912.3066137787677) E2
 = (652.3610166022207, -925.9980346419844) F2
 = (571.9686850386307, -1027.8283212891981) G2
 = (486.2168647041348, -1113.5801416236939) H2
 = (411.1840219114509, -1210.0509395000015)
I2
 = (320.072712806049, -1301.1622486054032) N2
 = (-982.9523991545551, 59.2940644758076) O2
 = (-996.3649078332896, 150.4991234912026) P2
 = (-1009.7774165120243, 544.8268786459984) Q2
 = (-1012.4599182477712, 458.9868231020972) R2
 = (-1025.8724269265058, 394.6067814441714) S2
 = (-1025.8724269265058, 327.5442380504986) T2
 = (-1023.1899251907588, 257.7991929210789) U2
 = (-929.3023644396168, 501.9068508740478) V2
 = (-891.74734013916, 456.3043213663503) W2
 = (-840.7798071599685, 416.0667953301467) Z2
 = (-800, 400) A3
 = (-631.5446717717091, 563.6043907962267) B3
 = (-679.8297030151535, 520.6843630242761) C3
 = (-709.3372221083696, 488.4943421953132) D3
 = (-730.797235994345, 434.844307480375) E3
 = (-626.1796683002152, 464.351826573591) F3
 = (-634.227173507456, 418.7492970658936) G3
 = (-634.227173507456, 332.9092415219924) H3
 = (-636.9096752432029, 268.5291998640666)
I3
 = (-634.227173507456, 209.5141616776346) J3
 = (-639.5921769789499, 147.8166217554557) K3
 = (-631.5446717717091, 83.4365800975298) L3
 = (-634.227173507456, 29.7865453825916) M3
 = (-475.9595710983879, 555.556885588986) N3
 = (-441.087048533678, 512.6368578170354) O3
 = (-414.2620311762088, 475.0818335165787) P3
 = (-376.707006875752, 437.5268092161219) Q3
 = (-253.3119270313939, 579.6994012107082) R3
 = (-274.7719409173692, 509.9543560812885) S3
 = (-285.5019478603569, 440.2093109518688) T3
 = (-306.9619617463322, 397.2892831799183) U3
 = (-320.3744704250668, 354.3692554079677) V3
 = (-336.4694808395483, 306.0842241645233) W3
 = (-363.2944981970175, 263.1641963925728) Z3
 = (-400, 200) A4
 = (-414.2620311762088, 134.4041130767211) B4
 = (-438.4045467979311, 83.4365800975298) C4
 = (-470.5945676268941, 21.7390401753509) D4
 = (-148.6943593372642, 582.381902946455) E4
 = (-148.6943593372642, 534.0968717030107) F4
 = (-154.059362808758, 464.351826573591) G4
 = (-162.1068680159987, 410.7017918586528) H4
 = (-162.1068680159987, 343.6392484649801)
I4
 = (-164.7893697517457, 281.9417085428012) J4
 = (-170.1543732232395, 230.9741755636099) K4
 = (-175.5193766947333, 166.594133905684) L4
 = (-178.2018784304802, 115.6266009264927) M4
 = (-178.2018784304802, 53.9290610043138) N4
 = (-81.6318159435913, 322.1792345790048) O4
 = (-9.2042690784245, 324.8617363147517) P4
 = (82.0007899369706, 587.7469064179489) Q4
 = (84.6832916727175, 512.6368578170354) R4
 = (84.6832916727175, 467.0343283093379) S4
 = (82.0007899369706, 405.336788387159) T4
 = (71.270782993983, 335.5917432577394) U4
 = (73.9532847297299, 281.9417085428012) V4
 = (76.6357864654768, 230.9741755636099) W4
 = (68.588281258236, 171.9591373771779) Z4
 = (68.588281258236, 112.9440991907458) A5
 = (76.6357864654768, 51.2465592685669) B5
 = (200, 600) C5
 = (197.348364574088, 539.4618751745045) D5
 = (197.348364574088, 496.541847402554) E5
 = (197.348364574088, 445.5743144233626) F5
 = (200, 400) G5
 = (194.6658628383411, 314.1317293717641) H5
 = (189.3008593668473, 247.0691859780913)
I5
 = (200, 200) J5
 = (194.6658628383411, 131.7216113409742) K5
 = (197.348364574088, 56.6115627400607) L5
 = (444.1385242628043, 587.7469064179489) M5
 = (417.3135069053352, 531.4143699672637) N5
 = (379.7584826048783, 437.5268092161219) O5
 = (366.3459739261437, 397.2892831799183) P5
 = (350.2509635116622, 338.2742449934863) Q5
 = (328.7909496256869, 295.3542172215357) R5
 = (299.2834305324709, 209.5141616776346) S5
 = (269.7759114392547, 150.4991234912026) T5
 = (468.2810398845265, 520.6843630242761) U5
 = (468.2810398845265, 442.8918126876158) V5
 = (465.5985381487796, 386.5592762369307) W5
 = (457.5510329415389, 332.9092415219924) Z5
 = (457.5510329415389, 273.8942033355604) A6
 = (460.2335346772858, 212.1966634133815) B6
 = (460.2335346772858, 158.5466286984433) C6
 = (452.186029470045, 96.8490887762644) D6
 = (452.186029470045, 51.2465592685669) Q1
 = (773.078408315713, 571.8700991849313) R1
 = (823.947772716421, 535.2998387802093) S1
 = (709.2530950310256, 599.315472837174) T1
 = (661.241369488302, 577.976928151519) U1
 = (623.8989162884059, 527.2978845230887) V1
 = (615.8969620312853, 481.953477066072) W1
 = (600, 400) Z1
 = (602.5603716027509, 321.9143919236602) J2
 = (602.5603716027509, 279.2373025523503) K2
 = (600, 200) L2
 = (613.2296439455783, 111.1962631528179) M2
 = (621.2315982026989, 41.8459929244395) E6
 = (663.9086875740089, -22.1696411325253) F6
 = (762.599456745163, 15.1728120673708) G6
 = (845.2863174020761, 84.5230822957493) H6
 = (965.3156312588851, 44.5133110101463)
I6
 = (978.6522216874195, 124.5328535813522) J6
 = (1000, 200) K6
 = (994.6561302016607, 289.9065748951778) L6
 = (1002.6580844587813, 364.59148129497) M6
 = (1015.9946748873157, 455.2802962090033) N6
 = (1037.3332195729706, 548.6364292087436) O6
 = (1109.3508078870561, 607.3174270942945) P6
 = (1128.0220344870042, 548.6364292087436) Q6
 = (1154.695215344073, 495.2900674946063) R6
 = (1176.0337600297278, 425.9397972662278) S6
 = (1200.0396228010898, 356.5895270378494) T6
 = (1208.0415770582104, 279.2373025523503) U6
 = (1200, 200) V6
 = (1224.0454855724515, 108.528945067111) W6
 = (1248.0513483438133, 23.1747663244914) Z6
 = (1202.153512926805, 157.1274597962023) A7
 = (1039.2851993919778, 273.0427460056736) B7
 = (1077.4345340938294, 277.4445923174256) C7
 = (1109.714740380011, 273.0427460056736) D7
 = (1158.135049809284, 277.4445923174256) N1
 = (840.4046348385895, 1468.6897040610797) O1
 = (973.3698585452286, 1384.9708595050477) P1
 = (1096.4858064217462, 1281.5534632887725) A2
 = (1200, 1200) B2
 = (1273.7727713639317, 1089.4925846014044) C2
 = (1357.4916159199638, 976.2259125550078) D2
 = (1400, 800) E7
 = (1436.2858225609352, 665.9737239061824) F7
 = (1470.7582879663603, 533.0085001995429) G7
 = (1490.456839626603, 395.1186385778428) H7
 = (1510.1553912868458, 267.0780527862641)
I7
 = (1485.5322017115423, 124.2635532495032) J7
 = (1391.9640813253889, -87.4958770981078) K7
 = (1273.7727713639317, -254.9335662101722) L7
 = (1170.355375147657, -387.8987899168117) M7
 = (1071.8626168464427, -575.035030689119) N7
 = (884.7263760741358, -757.2466335463657) O7
 = (758.7234550231125, -829.7087915645574) P7
 = (1008.3649422945465, -663.2811333836008) Q7
 = (1115.7376249919375, -472.6946215957314) R7
 = (1442.1698830942992, 29.2283528260315)'''

# %%
ll = ggg.split('\n')
mm=[]
for i in range(len(ll)):
  mm.append(ll[i].strip(' ABCDEFGHIJKLMNOPQRSTUVWXYZ0123456789='))
nn=[]
for i in range(len(mm)):
  if len(mm[i])>0:
    k=mm[i].strip('()').split(', ')
    nn.append(k)
oo=[]

for i in range(len(nn)):
  ooo=(float(nn[i][0]), float(nn[i][1]))

  oo.append(ooo)
  ooo=()
pp = oo
moon=np.array(pp)
# plt.scatter(moon[:,0],moon[:,1])
plt.xlim(-2500,2500)
plt.ylim(-2500,2500)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-19a454ef6131> in <cell line: 1>()
# ----> 1 ll = ggg.split('\n')
#       2 mm=[]
#       3 for i in range(len(ll)):
#       4   mm.append(ll[i].strip(' ABCDEFGHIJKLMNOPQRSTUVWXYZ0123456789='))
#       5 nn=[]
#
# NameError: name 'ggg' is not defined

# %%
M = len(moon)
b=[]
with open("moon.txt", "w") as f:
    f.write(str(M))
    f.write('\n')
    for i in range(M):
      f.write(str(moon[i,0])+' '+ str(moon[i,1])+'\n')
      b.append(str(moon[i,0])+' '+ str(moon[i,1])+'\n')
print(b)
# Out:
# ['-103.3269000955246 -1558.4177096088904\n', '-317.7064509317644 -1440.5089566489587\n', '-510.6480466843802 -1258.2863384381553\n', '-639.2757771861241 -1124.2991191655058\n', '-746.465552604244 -963.5144560383262\n', '-853.6553280223638 -781.2918378275228\n', '-928.6881708150478 -615.1476859294373\n', '-1035.8779462331677 -427.565578947728\n', '-1105.5513002549455 -320.3758035296083\n', '-1196.6626093603475 -164.9506291733349\n', '-1266.3359633821256 70.8668767465284\n', '-1319.9308510911853 215.5730735609899\n', '-1362.8067612584334 365.6387591463574\n', '-1394.9636938838694 585.3777987535027\n', '-1437.8396040511172 906.9471250078616\n', '0.0 -1638.81004117248\n', '105.6931619698092 -1563.7771983797963\n', '212.8829373879291 -1445.8684454198647\n', '-1000.0 1500.0\n', '-1116.2702777967577 1405.379580702118\n', '-1228.8195419857834 1308.9087828258102\n', '-1341.3688061748094 1212.4379849495026\n', '-1405.6826714256813 1099.888720760477\n', '-869.7337943350818 1496.4908898075196\n'
# ...
