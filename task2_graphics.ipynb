# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import csv
from matplotlib import pyplot as plt
f = open("heatmap_task1_data.txt")
a = []
for line in f:
    a.append(line.split())
f1 = open("heatmap_data.txt", 'w')
for i in a:
    f1.write(','.join(i))
    f1.write('\n')
f.close()
f1.close()

# %%
X = []
Y = []
with open('res1.txt', 'r') as datafile:
    plotting = csv.reader(datafile)
    for rows in plotting:
        rows = ''.join(rows).split()
        X.append(float(rows[0]))
        Y.append(float(rows[1]))
plt.tight_layout()
plt.axis([-2500,2500,-2500,2500])
plt.title('Распределение вихрей в сверхпроводнике')
plt.scatter(X,Y)

# %%
X = []
Y = []
with open('task1energy.txt', 'r') as datafile:
    plotting = csv.reader(datafile)
    for rows in plotting:
        rows = ''.join(rows).split()
        X.append(float(rows[0]))
        Y.append(float(rows[1]))
plt.ylabel('Energy, eV')
plt.xlabel('Iterations')
plt.title('Энергия системы')
plt.plot(X, Y)

# %% [markdown]
# **********'*****
# Кривая намагниченности

# %%
X = []
Y = []
with open('mc0-1000.txt', 'r') as datafile:
    plotting = csv.reader(datafile)
    for rows in plotting:
        rows = ''.join(rows).split()
        print(rows)
        X.append(float(rows[0]))
        Y.append(float(rows[1]))
plt.tight_layout()
#plt.axis([-2500,2500,-2500,2500])
plt.title('Magnetization curve')
plt.plot(X, Y)
plt.xlabel('H, Gs')
plt.ylabel('4$\\pi$M, Gs')
# Out:
# ['50.000000000000000', '0.82713383195296997']
# ['100.00000000000000', '0.82713383195296997']
# ['150.00000000000000', '0.82713383195296997']
# ['200.00000000000000', '0.82713383195296997']
# ['250.00000000000000', '0.82713383195296997']
# ['300.00000000000000', '10.752739815388610']
# ['350.00000000000000', '43.838093093507410']
# ['400.00000000000000', '2.4814014958589099']
# ['450.00000000000000', '17.369810471012372']
# ['500.00000000000000', '12.407007479294551']
# ['550.00000000000000', '61.207903564519775']
# ['600.00000000000000', '76.096312539673235']
# ['650.00000000000000', '6.6170706556237597']
# ['700.00000000000000', '43.010959261554440']
# ['750.00000000000000', '141.43988526395788']
# ['800.00000000000000', '48.800896085225233']
# ['850.00000000000000', '4.1356691597648503']
# ['900.00000000000000', '135.64994844028709']
# ['950.00000000000000', '33.912487110071773']
# ['1000.0000000000000', '170.38956938231183']
# Text(0, 0.5, '4$\\pi$M, Gs')

# %%
X = []
Y = []
with open('mc0-1000.txt', 'r') as datafile:
    plotting = csv.reader(datafile)
    for rows in plotting:
        rows = ''.join(rows).split()
        print(rows)
        X.append(float(rows[0]))
        Y.append(float(rows[1]))
plt.tight_layout()
#plt.axis([-2500,2500,-2500,2500])
plt.title('Magnetization curve')
plt.plot(X, Y)
plt.xlabel('H, Gs')
plt.ylabel('4$\\pi$M, Gs')
# Out:
# ['50.000000000000000', '50.000000000000000']
# ['100.00000000000000', '100.00000000000000']
# ['150.00000000000000', '150.00000000000000']
# ['200.00000000000000', '200.00000000000000']
# ['250.00000000000000', '249.17286616804702']
# ['300.00000000000000', '290.90152784851733']
# ['350.00000000000000', '302.02623774672776']
# ['400.00000000000000', '371.05031588164604']
# ['450.00000000000000', '373.07655362837380']
# ['500.00000000000000', '454.50763924258666']
# ['550.00000000000000', '486.31069493962133']
# ['600.00000000000000', '542.92776559524509']
# ['650.00000000000000', '634.28445719289357']
# ['700.00000000000000', '593.29973567806690']
# ['750.00000000000000', '641.64546801416088']
# ['800.00000000000000', '783.45732336094056']
# ['850.00000000000000', '687.88176893721788']
# ['900.00000000000000', '675.84673154074517']
# ['950.00000000000000', '937.59299252070548']
# ['1000.0000000000000', '998.34573233609410']
# Text(0, 0.5, '4$\\pi$M, Gs')
